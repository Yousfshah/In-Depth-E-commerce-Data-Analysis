# %% [markdown]
# <div style="padding: 15px; text-align: center; font-size: 30px; font-weight: bold; color: #FFFFFF; background: linear-gradient(to right, #6C7A89, #2E3440, #251075); border-bottom: 3px solid #D8DEE9;">
#   📈 Data Analysis On Pakistan Ecommerce Dataset 🚀
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <img src="add_banner.jpg" alt="Pakistan Biggest E-commerce Dataset" style="width: 100%; max-width: 800px; border-radius: 10px;"/>
# </div>
#
# ---

# %% [markdown]
# <style>
#   /* General Reset */
#   * {
#     margin: 0;
#     padding: 0;
#     box-sizing: border-box;
#   }
#
#   /* Author Info Section with Adaptive Backgrounds */
#   .author-info {
#     max-width: 600px;
#     margin: 20px auto;
#     padding: 20px;
#     border-radius: 10px;
#     border: 2px solid #155724;
#     font-family: Arial, sans-serif;
#     text-align: center;
#     color: #155724;
#   }
#
#   /* Light Mode Default */
#   @media (prefers-color-scheme: light) {
#     .author-info {
#       background-color: #d4edda;
#     }
#   }
#
#   /* Dark Mode Background */
#   @media (prefers-color-scheme: dark) {
#     .author-info {
#       background-color: #2a2f36;
#       color: #a6dba6;
#       border: 2px solid #86b500;
#     }
#   }
#
#   /* Contact Info Section */
#   .contact-info {
#     max-width: 600px;
#     margin: 10px auto;
#     padding: 15px;
#     border-radius: 10px;
#     font-family: Arial, sans-serif;
#     text-align: center;
#     background-color: #f8f9fa;
#   }
#
#   /* Dark mode for contact links */
#   @media (prefers-color-scheme: dark) {
#     .contact-info {
#       background-color: #1c1c1c;
#       color: #dcdcdc;
#     }
#   }
#
#   /* Table Styling for Social Links */
#   .contact-info table {
#     margin: 0 auto;
#     border-spacing: 10px;
#   }
#
#   .contact-info img {
#     height: 40px;
#     transition: transform 0.2s ease;
#   }
#
#   /* Hover Effect on Icons */
#   .contact-info img:hover {
#     transform: scale(1.1);
#   }
# </style>
#
# <div class="author-info">
#   <h3>Author Information</h3>
#   <p>
#     <strong>Author Name:</strong>
#     <a href="https://www.linkedin.com/in/yousuf-shah-7ba9492b4/" style="color: inherit; text-decoration: none;">Yousuf Shah</a>
#   </p>
#   <p>
#     <strong>Project Title:</strong> <span>EDA on Pakistan's E-Commerce Dataset</span>
#   </p>
# </div>
#
# <div class="contact-info">
#   <table>
#     <tr>
#       <td>
#         <a href="https://www.linkedin.com/in/yousuf-shah-7ba9492b4/" target="_blank">
#           <img src="https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin" alt="LinkedIn" />
#         </a>
#       </td>
#       <td>
#         <a href="https://yousfshah.github.io/Portfolio_Website/" target="_blank">
#           <img src="https://img.shields.io/badge/Portfolio_Website-Website-blue?style=for-the-badge&logo=link" alt="Portfolio Website" />
#         </a>
#       </td>
#     </tr>
#     <tr>
#       <td>
#         <a href="https://github.com/Yousfshah" target="_blank">
#           <img src="https://img.shields.io/badge/GitHub-Profile-green?style=for-the-badge&logo=github" alt="GitHub" />
#         </a>
#       </td>
#       <td>
#         <a href="https://www.kaggle.com/yousufshah" target="_blank">
#           <img src="https://img.shields.io/badge/Kaggle-Profile-orange?style=for-the-badge&logo=kaggle" alt="Kaggle" />
#         </a>
#       </td>
#     </tr>
#   </table>
# </div>

# %% [markdown]
# ---

# %% [markdown]
# <div style="padding: 15px; text-align: center; font-size: 30px; font-weight: bold; color: #FFFFFF; background: linear-gradient(to right, #6C7A89, #2E3440, #615e03); border-bottom: 3px solid #D8DEE9;">
# 🖋️ About Dataset
# </div>

# %% [markdown]
# ### **Context**
#
# This dataset represents the largest retail e-commerce orders dataset from Pakistan, covering a time span from March 2016 to August 2018. It consists of half a million transaction records, collected from various e-commerce merchants as part of a research study.
#
# The dataset was released as a capstone project for the Data Science course at Alnafi. It provides valuable insights into the emerging e-commerce potential in Pakistan and serves as a resource for startups, researchers, and students to explore trends, challenges, and opportunities in the local e-commerce market.
# Content
#
# -    Geography: Pakistan
# -    Time Period: March 2016 – August 2018
# -    Unit of Analysis: E-commerce orders
# -    Size: 101 MB
# -    File Type: CSV
#
# Key Features:
#
# - item_id: Unique identifier for each item in the dataset.
#
# - status: Status of the order (e.g., complete, canceled, refunded).
#
# - created_at: Date when the order was created.
#
# - sku: Stock Keeping Unit, a unique code identifying products.
#
# - price: Unit price of the item.
#
# - qty_ordered: Quantity of the item ordered.
#
# - grand_total: Total revenue generated by the item (price × quantity).
#
# - increment_id: Unique order identifier for transactions.
#
# - category_name_1: Primary product category associated with the item.
#
# - sales_commission_code: Commission code related to the sale of the item.
#
# - discount_amount: Discount applied to the item.
#
# - payment_method: Payment method used for the transaction (e.g., COD, credit card).
#
# - Working Date: The date when the order was processed.
#
# - BI Status: Business Intelligence status or categorization of the transaction.
#
# - MV: Market value of the item.
#
# - Year: Year of the transaction.
#
# - Month: Month of the transaction.
#
# - Customer Since: The starting date of the customer relationship.
#
# - M-Y: Month and year representation (e.g., 7-2016).
#
# - FY: Fiscal year (e.g., FY17).
#
# - Customer ID: Unique identifier for the customer.
#
# - Unnamed: 21 to Unnamed: 25: Empty columns with no data; likely irrelevant and should be dropped.
#
# ### **Purpose**
#
# This dataset enables analysis of Pakistan’s e-commerce sector, uncovering:
#
# -    Trends: Seasonal and product-wise.
# -    Customer Behavior: Payment preferences and shopping habits.
# -    Performance: Top-performing product categories and payment methods.
# -    Business Insights: Identifying growth opportunities for startups and established e-commerce platforms.
#
# ### **Source**
#
# The dataset was released by Zeeshan Usmani on Kaggle as part of a public contribution to the data science community. You can access the dataset [here](https://www.kaggle.com/datasets/zusmani/pakistans-largest-ecommerce-dataset)

# %% [markdown]
# ### **Inspiration**
#
# - What is the best-selling category?
# - Visualize payment method and order status frequency
# - Find a correlation between payment method and order status
# - Find a correlation between order date and item category
# - Find any hidden patterns that are counter-intuitive for a layman
# - Can we predict number of orders, or item category or number of customers/amount in advance?

# %% [markdown]
# ---

# %% [markdown]
# <div style="padding: 15px; text-align: center; font-size: 30px; font-weight: bold; color: #FFFFFF; background: linear-gradient(to right, #6C7A89, #2E3440); border-bottom: 3px solid #D8DEE9;">
#   📊 Importing Essential Libraries
# </div>
#
# <div style="padding: 15px; margin: 10px 0; text-align: left; color: #333; background: linear-gradient(to right, #ECEFF4, #D8DEE9, #91d44e); border-radius: 5px;">
#   <p style="font-size: 16px; line-height: 1.6;">
#     ⚙️ <b>Numpy:</b> For numerical computations and array manipulation.<br>
#     🐼 <b>Pandas:</b> Efficiently handles data manipulation with DataFrames.<br>
#     📊 <b>Matplotlib:</b> Visualization of datasets using plots and graphs.<br>
#     📊 <b>Seaborn:</b> Advanced statistical visualization built on Matplotlib.<br>
#     🔮 <b>Plotly Express:</b> Interactive data visualization for dashboards and reports.
#   </p>
# </div>

# %%
# Data manipulation libraries
import pandas as pd
import numpy as np

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# To ensure that plots are displayed inline in jupyter notebook
# %matplotlib inline


# remove warnings 
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# <div style="padding: 15px; text-align: center; font-size: 30px; font-weight: bold; color: #FFFFFF; background: linear-gradient(to right, #6C7A89, #2E3440, #660960); border-bottom: 3px solid #D8DEE9;">
#   🔍 Data Exploration
# </div>

# %%
# read data
df = pd.read_csv(r"D:\App_Dataset\Pakistan_Largest_Ecommerce_Dataset.csv")

# %%
# Check the shape
print(f'Number of rows : {df.shape[0]}')
print(f'Number of columns : {df.shape[1]}')
# Out:
# Number of rows : 1048575
# Number of columns : 26

# %%
# View column names
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
# Show all columns
pd.set_option('display.max_columns', None)

# Display the first few rows 
df.head()
# Out:
#    item_id          status created_at  \
# 0   211131        complete   7/1/2016
# 1   211133        canceled   7/1/2016
# 2   211134        canceled   7/1/2016
# 3   211135        complete   7/1/2016
# 4   211136  order_refunded   7/1/2016
#
#                                                  sku  price  qty_ordered  \
# 0                                  kreations_YI 06-L   1950            1
# 1  kcc_Buy 2 Frey Air Freshener & Get 1 Kasual Bo...    240            1
# 2                                 Ego_UP0017-999-MR0   2450            1
# 3                                     kcc_krone deal    360            1
# 4                                        BK7010400AG    555            2
#
#    grand_total increment_id    category_name_1 sales_commission_code  \
# 0         1950    100147443    Women's Fashion                    \N
# 1          240    100147444  Beauty & Grooming                    \N
# 2         2450    100147445    Women's Fashion                    \N
# ...

# %%
# check data types
df.dtypes
# Out:
# item_id                  float64
# status                    object
# created_at                object
# sku                       object
# price                    float64
# qty_ordered              float64
# grand_total              float64
# increment_id              object
# category_name_1           object
# sales_commission_code     object
# discount_amount          float64
# payment_method            object
# Working Date              object
# BI Status                 object
#  MV                       object
# Year                     float64
# Month                    float64
# Customer Since            object
# M-Y                       object
# FY                        object
# Customer ID              float64
# Unnamed: 21              float64
# Unnamed: 22              float64
# Unnamed: 23              float64
# Unnamed: 24              float64
# Unnamed: 25              float64
# dtype: object

# %% [markdown]
# ### Observation
# - By default, pandas store all columns as float or object. However, our dataset contains a mix of data types, including categorical, integer, float, and datetime values.
#
# - During the data cleaning process, I will explicitly convert each column to its appropriate data type. This step ensures memory optimization, improves processing efficiency, and allows for accurate analysis.

# %%
# info of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   item_id                584524 non-null  float64
#  1   status                 584509 non-null  object
#  2   created_at             584524 non-null  object
#  3   sku                    584504 non-null  object
#  4   price                  584524 non-null  float64
#  5   qty_ordered            584524 non-null  float64
#  6   grand_total            584524 non-null  float64
#  7   increment_id           584524 non-null  object
#  8   category_name_1        584360 non-null  object
#  9   sales_commission_code  447346 non-null  object
#  10  discount_amount        584524 non-null  float64
#  11  payment_method         584524 non-null  object
#  12  Working Date           584524 non-null  object
#  13  BI Status              584524 non-null  object
# ...

# %% [markdown]
# ### **Observation**
# - Total rows: 1,048,575
# - Valid entries in key columns: 584,524
# - completely empty columns: Unnamed: 21 to Unnamed: 25
#
# - `Working Date`, `created_at`, `Year`, `Month`, `M-Y`, `FY` and `Customer Since` are datetime values
#
# - `status`, `sales_commission_code`, `sku`, `payment_method`, `category_name_1` and `BI Status` are objects
#
# - `price`, `qty_ordered`, `Customer ID`,  `increment_id`, `grand_total`, `item_id`, `MV`and `discount_amount` are numerical fields

# %%
# Set Pandas to display numbers without scientific notation
pd.set_option('display.float_format', '{:.0f}'.format)

# summary statistics
df.describe()
# Out:
#        item_id   price  qty_ordered  grand_total  discount_amount   Year  \
# count   584524  584524       584524       584524           584524 584524
# mean    565667    6349            1         8531              499   2017
# std     200121   14949            4        61321             1507      1
# min     211131       0            1        -1594             -600   2016
# 25%     395001     360            1          945                0   2017
# 50%     568424     899            1         1960                0   2017
# 75%     739106    4070            1         6999              160   2018
# max     905208 1012626         1000     17888000            90300   2018
#
#        Month  Customer ID  Unnamed: 21  Unnamed: 22  Unnamed: 23  Unnamed: 24  \
# count 584524       584513            0            0            0            0
# mean       7        45791          NaN          NaN          NaN          NaN
# ...

# %% [markdown]
# ### Observation
# - Price
#     - The <span style="color:blue;">average price</span> is <span style="color:red;">6349</span> with a <span style="color:blue;">standard deviation</span> of <span style="color:red;">14949</span>
#     - Prices range from a <span style="color:blue;">minimum</span> of <span style="color:red;">0</span> to a <span style="color:blue;">maximum</span> of <span style="color:red;">1,012,626</span> indicating a significant range in product pricing.
#
# - qty_ordered
#     - The <span style="color:blue;">average qty_ordered</span> is <span style="color:red;">1</span>, with a <span style="color:blue;">standard deviation</span> of <span style="color:red;">4</span>.
#     - Orders range from a <span style="color:blue;">minimum</span> of <span style="color:red;">1</span> to a <span style="color:blue;">maximum</span> of <span style="color:red;">1000</span>, suggesting that most orders have low quantities, but there are significant outliers with very high order counts.
#
# - grand_total
#     - The <span style="color:blue;">average grand total</span> is <span style="color:red;">8,531</span>, with a <span style="color:blue;">standard deviation</span> of <span style="color:red;">61,321</span>, indicating that there is high variability in total purchase.
#     - The <span style="color:blue;">minimum</span> is <span style="color:red;">-1549</span> (indicating negative grand totals for some reason), while the <span style="color:blue;">maximum</span> is <span style="color:red;">17,888,000</span>.
# - discount_amount
#     - The <span style="color:blue;">average discount_amount</span> is <span style="color:red;">499</span>, with a <span style="color:blue;">standard deviation</span> of <span style="color:red;">1507</span>, showing that discounts vary significantly across orders.
#     - Discount amounts range from <span style="color:red;">-600</span> to <span style="color:red;">90,300</span> (indicating negative discount_amount for some reason), suggesting that some high discounts.

# %%
# See Missing Values

# Create a copy of the DataFrame
df_missing = df.copy()

# Calculate missing values and their percentage
missing_data = df_missing.isnull().sum().sort_values(ascending=False).reset_index()
missing_data.columns = ['Columns Name', 'Missing Values']
missing_data['Percentage Missing Values'] = (missing_data['Missing Values'] / len(df_missing)) * 100

missing_data
# Out:
#              Columns Name  Missing Values  Percentage Missing Values
# 0             Unnamed: 23         1048575                        100
# 1             Unnamed: 22         1048575                        100
# 2             Unnamed: 25         1048575                        100
# 3             Unnamed: 24         1048575                        100
# 4             Unnamed: 21         1048575                        100
# 5   sales_commission_code          601229                         57
# 6         category_name_1          464215                         44
# 7                     sku          464071                         44
# 8                  status          464066                         44
# 9          Customer Since          464062                         44
# 10            Customer ID          464062                         44
# 11           increment_id          464051                         44
# 12            grand_total          464051                         44
# ...

# %%
# Visualize Missing Values

# Filter columns with missing values > 0 for visualization
missing_data_filtered = missing_data[missing_data['Missing Values'] > 0]

# Visualization
plt.figure(figsize=(10, 6))
plt.bar(missing_data_filtered['Columns Name'], missing_data_filtered['Percentage Missing Values'], color='blue')
plt.title('Percentage of Missing Values by Column', fontsize=16)
plt.xlabel('Columns', fontsize=14)
plt.ylabel('Percentage Missing (%)', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Observation
# - Columns with high missing percentages or unrelated information will be removed.
# - Rows with all missing values or excessive missing data will be dropped.
# - Missing values in important columns may be handled using appropriate imputation techniques.

# %%
# Check if there are any duplicate rows
duplicates = df.duplicated()

# Count of total duplicates
total_duplicates = df.duplicated().sum()

print(f"Total number of duplicate rows in the data: {total_duplicates}")
# Out:
# Total number of duplicate rows in the data: 464050

# %% [markdown]
# ### Observation
# - The dataset contains a significant number of duplicate rows, primarily due to the presence of many missing values. After completing the data cleaning process handling missing values and removing unnecessary rows. Dataset will no longer have any duplicate rows.

# %%
# DataFrames with unique values from different columns
unique_status = pd.DataFrame({'unique_status': df['status'].unique()})
unique_payment_method = pd.DataFrame({'unique_payment_method': df['payment_method'].unique()})
unique_category_name_1 = pd.DataFrame({'unique_category_name_1': df['category_name_1'].unique()})
unique_bi_status = pd.DataFrame({'unique_BI_Status': df['BI Status'].unique()})

# Concatenate them into a single DataFrame
merged_df = pd.concat([unique_status, unique_payment_method, unique_category_name_1, unique_bi_status], axis=1)

# Display result
merged_df
# Out:
#      unique_status unique_payment_method unique_category_name_1  \
# 0         complete                   cod        Women's Fashion
# 1         canceled         ublcreditcard      Beauty & Grooming
# 2   order_refunded             mygateway                Soghaat
# 3         received        customercredit      Mobiles & Tablets
# 4           refund        cashatdoorstep             Appliances
# 5           closed               mcblite          Home & Living
# 6            fraud       internetbanking          Men's Fashion
# 7           holded      marketingexpense            Kids & Baby
# 8         exchange         productcredit                     \N
# 9   pending_paypal     financesettlement                 Others
# 10            paid               Payaxis          Entertainment
# 11              \N           jazzvoucher              Computing
# 12             cod            jazzwallet             Superstore
# 13         pending               Easypay        Health & Sports
# ...

# %% [markdown]
# ### 🧐  Observation
# - `\N` and `NaN`: Represent missing or invalid data.

# %% [markdown]
# <div style="background: linear-gradient(135deg, #6a11cb 0%, #2575fc 100%); color: white; padding: 20px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: Arial, sans-serif; animation: fadeIn 2s;">
#     <h1 style="text-align: center; font-size: 2em; margin-bottom: 10px;">🎉 Congratulations!</h1>
#     <p style="text-align: center; font-size: 1.2em;">
#         We have successfully completed the <strong>Data Exploration</strong> phase. Now, it's time to move forward into the <strong>Data Cleaning</strong> process.
#     </p>
#     <p style="text-align: center; font-size: 1.2em; margin-top: 10px;">
#         Let's jump into it together! 🚀
#     </p>
# </div>
#
# <style>
#     @keyframes fadeIn {
#         from {
#             opacity: 0;
#         }
#         to {
#             opacity: 1;
#         }
#     }
# </style>

# %% [markdown]
# ---

# %% [markdown]
# <div style="padding: 15px; text-align: center; font-size: 30px; font-weight: bold; color: #FFFFFF; background: linear-gradient(to right, #6C7A89, #2E3440, #078574, #bf0404); border-bottom: 3px solid #D8DEE9;">
# 🧹 Data Cleaning
# </div>

# %%
# remove Unnecessary columns
df.drop(['Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'], axis=1, inplace=True)
print("Unnecessary columns ('Unnamed: 21, to 'Unnamed: 25') have been successfully dropped from the dataset")
# Out:
# Unnecessary columns ('Unnamed: 21, to 'Unnamed: 25') have been successfully dropped from the dataset

# %%
# I will drop the 'sales_commission_code' column due to over 50% missing values, as it is not suitable for filling due to its uniqueness
df.drop('sales_commission_code', axis=1, inplace=True)
print("'sales_commission_code' column has been successfully dropped from the dataset")
# Out:
# 'sales_commission_code' column has been successfully dropped from the dataset

# %%
# Check Missing Values
percentage_missing = (df.isnull().sum() / len(df)) * 100
percentage_missing = percentage_missing.map("{:.0f}%".format)
percentage_missing
# Out:
# item_id            44%
# status             44%
# created_at         44%
# sku                44%
# price              44%
# qty_ordered        44%
# grand_total        44%
# increment_id       44%
# category_name_1    44%
# discount_amount    44%
# payment_method     44%
# Working Date       44%
# BI Status          44%
#  MV                44%
# Year               44%
# Month              44%
# Customer Since     44%
# M-Y                44%
# FY                 44%
# Customer ID        44%
# dtype: object

# %% [markdown]
# ### Let's deal with missing values

# %%
# Our data has so many rows with entirely NaN values so we have to remove 
df.tail(8)
# Out:
#          item_id status created_at  sku  price  qty_ordered  grand_total  \
# 1048567      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048568      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048569      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048570      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048571      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048572      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048573      NaN    NaN        NaN  NaN    NaN          NaN          NaN
# 1048574      NaN    NaN        NaN  NaN    NaN          NaN          NaN
#
#         increment_id category_name_1  discount_amount payment_method  \
# 1048567          NaN             NaN              NaN            NaN
# 1048568          NaN             NaN              NaN            NaN
# 1048569          NaN             NaN              NaN            NaN
# ...

# %%
# it will remove rows where all records are empty
df.dropna(how='all', inplace=True)
print("Rows with all values missing have been successfully dropped from the dataset")
# Out:
# Rows with all values missing have been successfully dropped from the dataset

# %%
# now see missing values
df.isnull().sum()
# Out:
# item_id              0
# status              15
# created_at           0
# sku                 20
# price                0
# qty_ordered          0
# grand_total          0
# increment_id         0
# category_name_1    164
# discount_amount      0
# payment_method       0
# Working Date         0
# BI Status            0
#  MV                  0
# Year                 0
# Month                0
# Customer Since      11
# M-Y                  0
# FY                   0
# Customer ID         11
# dtype: int64

# %%
# Fill missing values in 'status', 'category_name_1', and 'Customer Since' with their respective mode 
# because These columns contain categorical data
df['status'].fillna(df['status'].mode()[0], inplace=True)
df['category_name_1'].fillna(df['category_name_1'].mode()[0], inplace=True)
df['Customer Since'].fillna(df['Customer Since'].mode()[0], inplace=True)

# Drop rows where 'sku' or 'Customer ID' have missing values
# becuase 'sku' and 'Customer ID' are unique 
df.dropna(subset=['sku', 'Customer ID'], inplace=True)

# Display a message confirming the operation
print("Missing values filled for 'status', 'category_name_1', and 'Customer Since'.")
print("Rows with missing values in 'sku' or 'Customer ID' have been dropped.")
# Out:
# Missing values filled for 'status', 'category_name_1', and 'Customer Since'.
# Rows with missing values in 'sku' or 'Customer ID' have been dropped.

# %%
# successfully we deal with missing values
df.isnull().sum()
# Out:
# item_id            0
# status             0
# created_at         0
# sku                0
# price              0
# qty_ordered        0
# grand_total        0
# increment_id       0
# category_name_1    0
# discount_amount    0
# payment_method     0
# Working Date       0
# BI Status          0
#  MV                0
# Year               0
# Month              0
# Customer Since     0
# M-Y                0
# FY                 0
# Customer ID        0
# dtype: int64

# %%
# handle data inconsistency

# Remove 'FY' from the column name FY
df['FY'] = df['FY'].str.replace('FY', '', regex=True)

# Rename columns with meaningful names
df.rename(columns={
    ' MV ': 'market_value',
    'M-Y': 'month_year',
    'FY': 'fiscal_year',
    'sku': 'stock_keeping_unit', 
    'Customer Since': 'customer_since',
    'category_name_1': 'category',
    'BI Status': 'bi_status',
    'Working Date': 'working_date'
}, inplace=True)


# Our dataset has \\N So Replace '\\N' with NaN and drop rows containing NaN values
df.replace('\\N', pd.NA, inplace=True)  # Convert '\\N' to NaN
df.dropna(how='any', inplace=True)  # Drop rows that contain NaN in any column

print("Handle Data Inconsistency completed successfully")

# %%
# Fix Data Types
# as we mention above in data exploration part 


# 1. Convert date-related columns to datetime
date_columns = ['working_date', 'created_at', 'customer_since', 'Year', 'Month', 'month_year', 'fiscal_year']
df[date_columns] = df[date_columns].apply(pd.to_datetime, errors='coerce')

# 2. Convert specified columns into categorical type
categorical_columns = ['status', 'payment_method', 'category', 'bi_status', 'stock_keeping_unit']
df[categorical_columns] = df[categorical_columns].astype('category')

# 3. Convert specified columns into integer type
integer_columns = ['price', 'qty_ordered', 'Customer ID', 'increment_id', 'grand_total', 'item_id', 'market_value', 'discount_amount']
df[integer_columns] = df[integer_columns].apply(pd.to_numeric, errors='coerce').astype(int)

print("Data type conversion process completed successfully")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[242], line 7
#       1 # Fix Data Types
#       2 # as we mention above in data exploration part
#       3
#       4
#       5 # 1. Convert date-related columns to datetime
#       6 date_columns = ['Working Date', 'created_at', 'Customer Since', 'Year', 'Month', 'M-Y', 'FY']
# ----> 7 df[date_columns] = df[date_columns].apply(pd.to_datetime, errors='coerce')
#       9 # 2. Convert specified columns into categorical type
#      10 categorical_columns = ['status', 'payment_method', 'category_name_1', 'BI Status', 'sku']
#
# File c:\Users\Yousuf\AppData\Local\miniconda3\envs\DS-Env\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
# ...

# %%
# Review the data types
print(df.dtypes)
